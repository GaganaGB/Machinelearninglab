# %% [markdown]
# <a href="https://colab.research.google.com/github/GaganaGB/Iris-Data-E1-/blob/main/exper1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()

# Convert into DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)

print("First 5 rows:")
print(df.head())

# 1. Identify missing values
print("\nMissing values:")
print(df.isnull().sum())

# 2. Fill missing values with mean
df = df.fillna(df.mean())

print("\nMissing values after filling:")
print(df.isnull().sum())

# 3. Find correlation between features
corr = df.corr()

print("\nCorrelation Matrix:")
print(corr)

# 4. Identify highly correlated features
print("\nHighly correlated features:")

for i in range(len(corr.columns)):
    for j in range(i + 1, len(corr.columns)):
            if abs(corr.iloc[i, j]) > 0.7:
                        print(corr.columns[i], "and", corr.columns[j])

                        # 5. Visualize correlation using heatmap
                        plt.figure(figsize=(8, 6))

                        sns.heatmap(corr, annot=True, cmap="coolwarm")

                        plt.title("Correlation Heatmap - Iris Dataset")
                        plt.show()

# %%
import pandas as pd
df = pd.read_csv("/content/irisdata.csv")

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()

# Convert into DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)

print("First 5 rows:")
print(df.head())

# 1. Identify missing values
print("\nMissing values:")
print(df.isnull().sum())

# 2. Fill missing values with mean
df = df.fillna(df.mean())

print("\nMissing values after filling:")
print(df.isnull().sum())

# 3. Find correlation between features
corr = df.corr()

print("\nCorrelation Matrix:")
print(corr)

# 4. Identify highly correlated features
print("\nHighly correlated features:")

for i in range(len(corr.columns)):
    for j in range(i + 1, len(corr.columns)):
            if abs(corr.iloc[i, j]) > 0.7:
                        print(corr.columns[i], "and", corr.columns[j])

                        # 5. Visualize correlation using heatmap
                        plt.figure(figsize=(8, 6))

                        sns.heatmap(corr, annot=True, cmap="coolwarm")

                        plt.title("Correlation Heatmap - Iris Dataset")
                        plt.show()
# Out:
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Missing values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64
#
# Missing values after filling:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64
#
# Correlation Matrix:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# ...

# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
df = pd.read_csv("/content/titanic.csv")

# Load Titanic dataset
df = sns.load_dataset("titanic")

print("Original Data:")
print(df.head())

# 1. Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# 2. Handle missing values

# Age -> median
df["age"] = df["age"].fillna(df["age"].median())

# Embarked -> mode
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

# 3. Remove duplicate rows
df = df.drop_duplicates()

# 4. Encode categorical columns
df["sex"] = df["sex"].map({"male": 0, "female": 1})

df["embarked"] = LabelEncoder().fit_transform(df["embarked"])

# 5. Select useful features
X = df[[
    "pclass",
        "sex",
            "age",
                "sibsp",
                    "parch",
                        "fare",
                            "embarked"
                            ]]

y = df["survived"]

                            # 6. Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

                            # Convert back to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print("\nPrepared Data:")
print(X_scaled.head())

print("\nShape:")
print(X_scaled.shape)
# Out:
# Original Data:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Missing Values:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# ...
